# %% [markdown]
# <a href="https://colab.research.google.com/github/Raden616Rizki/PCVK_Ganjil_2023/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **A. PRAKTIKUM**

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # untuk menampilkan image
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
# Membuat list untuk menyimpan URL dari beberapa Image
urls = ['https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg',
        'https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg',
        'https://placekitten.com/800/571']

# Baca dan Tampilkan Image
# Loop pada tiap URL Image, beberapa Image dapat disimpan pada List
for url in urls:
  print(f'URL : {url}')

  # Membandingkan Image
  print('- Membandingkan Image')
  image = io.imread(url)                                  # Read Image
  image = cv.resize(image, (0, 0), fx = 0.5, fy = 0.5)    # Resize Image to Half Size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)          # Convert Color to RGB
  final_frame = cv.hconcat((image, image_2))              # Concatenate Image
  cv2_imshow(final_frame)                                 # Show Image
  print('\n')

  # Menampilkan Resolusi Image
  print('- Menampilkan Resolusi Image')
  tinggi = image_2.shape[0]
  lebar = image_2.shape[1]
  print(f'Resolusi Image : tinggi x lebar = {tinggi} x {lebar}')
  cv2_imshow(image_2)                                     # Show Image
  print('\n')

  # Menambahkan Garis Potong Horizontal
  print('- Menambahkan Garis Potong  Horizontal')
  image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)          # Convert Color to RGB

  # a. Membuat Garis Horizontal ditengah Image
  for y in range(lebar):
    image_3[int((tinggi/2)), y] = [255, 255, 255]

  final_frame = cv.hconcat((image_2, image_3))
  cv2_imshow(final_frame)                                 # Show Image
  print('\n')
# Out:
# URL : https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg
# - Membandingkan Image
# <PIL.Image.Image image mode=RGB size=800x276>
# - Menampilkan Resolusi Image
# Resolusi Image : tinggi x lebar = 276 x 400
# <PIL.Image.Image image mode=RGB size=400x276>
# - Menambahkan Garis Potong  Horizontal
# <PIL.Image.Image image mode=RGB size=800x276>
# URL : https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg
# - Membandingkan Image
# <PIL.Image.Image image mode=RGB size=800x286>
# - Menampilkan Resolusi Image
# Resolusi Image : tinggi x lebar = 286 x 400
# <PIL.Image.Image image mode=RGB size=400x286>
# - Menambahkan Garis Potong  Horizontal
# <PIL.Image.Image image mode=RGB size=800x286>
# URL : https://placekitten.com/800/571
# - Membandingkan Image
# <PIL.Image.Image image mode=RGB size=800x286>
# - Menampilkan Resolusi Image
# Resolusi Image : tinggi x lebar = 286 x 400
# <PIL.Image.Image image mode=RGB size=400x286>
# - Menambahkan Garis Potong  Horizontal
# ...

# %% [markdown]
# **B. JAWABAN PERTANYAAN**
#
# 1. Karena mudah dan gratis untuk digunakan, selain itu Google Colab juga dapat dihubungkan ke Github, kemudian Google Colab selain memiliki Library Python yang siap digunakan atau bawaan, juga dapat dilakukan penambahan Library Python yang diperlukan dengan menginstall terlebih dahulu Library yang diperlukan, sehingga selanjutnya dapat diimport.
#
# 2. Library yang terdapat pada Praktikum kali ini:
#
#   a. Numpy : digunakan untuk membuat dan memanipulasi array, aljabar linear, dan mengacak nomor
#
#   b. Pandas : digunakan untuk menampilkan, memanipulasi dan menganalisis data
#
#   c. CV2 : digunakan untuk melakukan tugas Visi Komputer
#
#   d. Skimage : digunakan untuk mendukung pemrosesan Image pada python
#
#   e. Matplotlib : menghasilkan Image dan menyediakan perangkat antarmuka pengguna grafis
#
#   f. PIL : digunakan untuk memanipulasi dan menyimpan format file Image
#
#   g. google.colab.patch : untuk menampilkan Image
#
#   Namun yang digunakan pada praktikum saat ini masih Skimage untuk memperoleh image dari URL dan CV2 untuk pengolahan Image
#
# 3. Kode tersebut digunakan untuk mengubah ukuran dari fx dan fy jadi setengah ukuran aslinya jika ukuran asli 571 x 800, maka ukuran setelah di resize menjadi 286 x 400, sehingga lebih ringan untuk diproses.
#
# 4. Kode tersebut digunakan untuk mewakili warna putih, karena setiap pixel terdiri dari 3 lapis merah, hijau, biru. Saat ke tiga warna ini berada pada kecerahan atau kondisi maksimal yaitu kode 255 maka akan dikombinasikan menjadi warna putih pada pixel tersebut.
#
# 5. Semakin tinggi resolusi pada gambar, maka semakin banyak pixel yang dibutuhkan untuk membentuk gambar tersebut.

# %% [markdown]
# **C. TUGAS**

# %%
urls = ['https://placekitten.com/800/571']
image = io.imread(url)
image = cv.resize(image, (0, 0), fx = 0.5, fy = 0.5)
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_4 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_5 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_6 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

tinggi = image_3.shape[0]
lebar = image_3.shape[1]

# Menampilkan Garis Vertikal
print('Menampilkan Garis Vertikal')
for x in range(tinggi):
    image_3[x, int((lebar/2))] = [255, 255, 255]

final_frame_1 = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame_1)

print('\n')

# Menampilkan Garis Diagonal
print('Menampilkan Garis Diagonal')
for y in range(lebar):
    image_4[int((tinggi/lebar*y)), y] = [255, 255, 255]
    image_4[int((tinggi/lebar*y)), -y] = [255, 255, 255]

final_frame_2 = cv.hconcat((image_2, image_4))
cv2_imshow(final_frame_2)

print('\n')

# Menampilkan Garis Putus dengan Panjang tertentu di Tengah Gambar
print('Menampilkan Garis Putus dengan Panjang tertentu di Tengah Gambar')
for y in range(lebar):
    if (y > lebar / 4 and y < lebar / 2):
      image_5[int((tinggi/2)), y] = [255, 255, 255]

final_frame_3 = cv.hconcat((image_2, image_5))
cv2_imshow(final_frame_3)

print('\n')

# Menampilkan Kotak Putih
print('Menampilkan Kotak Putih')
for y in range(lebar):
  for x in range(tinggi):
    if (x > tinggi / 3 and x < tinggi * 2 / 3 and y > lebar / 4 and y < lebar / 2):
      image_6[x, y] = [255, 255, 255]

final_frame_4 = cv.hconcat((image_2, image_6))
cv2_imshow(final_frame_4)
# Out:
# Menampilkan Garis Vertikal
# <PIL.Image.Image image mode=RGB size=800x286>
# Menampilkan Garis Diagonal
# <PIL.Image.Image image mode=RGB size=800x286>
# Menampilkan Garis Putus dengan Panjang tertentu di Tengah Gambar
# <PIL.Image.Image image mode=RGB size=800x286>
# Menampilkan Kotak Putih
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# **Tugas Kelompok**
